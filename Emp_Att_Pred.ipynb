# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

#pd.options.display.max_columns = 100
#pd.options.display.max_rows = 100

# %%
emp = pd.read_csv('Emp_Data.csv')

# %%
emp.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
emp.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
emp.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
emp['Education'] = emp.Education.astype('category')
sns.histplot(data=emp, x='Gender', hue='Attrition', stat='count', legend=True, palette='cubehelix')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Count'>

# %%
sns.histplot(data=emp, x='Age', hue='Attrition', stat='count', legend=True, palette='cubehelix', kde=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.catplot(data=emp, x='Education', kind='count', hue='Attrition', palette='cubehelix')

# %%
sns.histplot(data=emp, x='YearsAtCompany', hue='Attrition', stat='count', legend=True, palette='cubehelix', kde=True)
# Out:
# <AxesSubplot:xlabel='YearsAtCompany', ylabel='Count'>

# %%
sns.histplot(data=emp, x='MonthlyIncome', hue='Attrition', stat='count', legend=True, palette='cubehelix', kde=True)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Count'>

# %%
sns.catplot(data=emp, x='JobRole', kind='count', hue='Attrition', palette='cubehelix', height=20)

# %%
sns.catplot(data=emp, x='MaritalStatus', kind='count', hue='Attrition', palette='cubehelix', height=5)

# %%
sns.histplot(data=emp, x='PercentSalaryHike', hue='Attrition', stat='count', legend=True, palette='cubehelix', kde=True)
# Out:
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='Count'>

# %%
sns.histplot(data=emp, x='JobSatisfaction', hue='Attrition', stat='count', legend=True, palette='cubehelix', discrete=True)
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='Count'>

# %%
sns.histplot(data=emp, x='PerformanceRating', hue='Attrition', stat='count', legend=True, palette='cubehelix', kde=True)
# Out:
# <AxesSubplot:xlabel='PerformanceRating', ylabel='Count'>

# %%
sns.histplot(data=emp, x='DistanceFromHome', hue='Attrition', stat='count', legend=True, palette='cubehelix', kde=True)
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='Count'>

# %%
sns.histplot(data=emp, x='YearsSinceLastPromotion', hue='Attrition', stat='count', legend=True, palette='cubehelix', kde=True)
# Out:
# <AxesSubplot:xlabel='YearsSinceLastPromotion', ylabel='Count'>

# %%
sns.catplot(data=emp, x='Department', kind='count', hue='Attrition', palette='cubehelix', height=10)

# %%
emp['StockOptionLevel'] = emp.StockOptionLevel.astype('category')
sns.catplot(data=emp, x='StockOptionLevel', kind='count', hue='Attrition', palette='cubehelix', height=10)

# %%
sns.catplot(data=emp, x='Attrition', kind='count', palette='cubehelix', height=10)

# %%
emp = pd.get_dummies(emp, columns=['StockOptionLevel', 'MaritalStatus', 'BusinessTravel', 'JobLevel', 'JobRole', 'Education', 'EducationField', 'Department'])

# %%
emp.drop(['Over18', 'EmployeeNumber'], axis=1, inplace=True)

# %%
emp.Gender = emp.Gender.map(dict(Male=1, Female=0))
emp.OverTime = emp.OverTime.map(dict(Yes=1, No=0))
emp.Attrition = emp.Attrition.map(dict(Yes=1, No=0))
emp.Attrition =emp.Attrition.astype('int64')

# %%
emp.columns
# Out:
# Index(['Age', 'Attrition', 'DailyRate', 'DistanceFromHome', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'StockOptionLevel_0', 'StockOptionLevel_1', 'StockOptionLevel_2',
#        'StockOptionLevel_3', 'MaritalStatus_Divorced', 'MaritalStatus_Married',
#        'MaritalStatus_Single', 'BusinessTravel_Non-Travel',
#        'BusinessTravel_Travel_Frequently', 'BusinessTravel_Travel_Rarely',
#        'JobLevel_1', 'JobLevel_2', 'JobLevel_3', 'JobLevel_4', 'JobLevel_5',
#        'JobRole_Healthcare Representative', 'JobRole_Human Resources',
# ...

# %%
emp.head()
# Out:
#    Age  Attrition  DailyRate  DistanceFromHome  EmployeeCount  \
# 0   41          1       1102                 1              1
# 1   49          0        279                 8              1
# 2   37          1       1373                 2              1
# 3   33          0       1392                 3              1
# 4   27          0        591                 2              1
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  \
# 0                        2       0          94               3
# 1                        3       1          61               2
# 2                        4       1          92               2
# 3                        4       0          56               3
# 4                        1       1          40               3
#
#    JobSatisfaction  MonthlyIncome  MonthlyRate  NumCompaniesWorked  OverTime  \
# 0                4           5993        19479                   8         1
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
emp.dropna()
X = emp[['YearsSinceLastPromotion', 'JobSatisfaction', 'Age', 'PerformanceRating', 'YearsAtCompany', 'Gender',      'RelationshipSatisfaction', 'EnvironmentSatisfaction', 'HourlyRate', 'MonthlyIncome', 'PercentSalaryHike', 'TotalWorkingYears', 'WorkLifeBalance', 'YearsSinceLastPromotion', 'MaritalStatus_Divorced', 'MaritalStatus_Married', 'MaritalStatus_Single', 'BusinessTravel_Non-Travel', 'BusinessTravel_Travel_Frequently', 'BusinessTravel_Travel_Rarely',
       'JobLevel_1', 'JobLevel_2', 'JobLevel_3', 'JobLevel_4', 'JobLevel_5',
       'JobRole_Healthcare Representative', 'JobRole_Human Resources',
       'JobRole_Laboratory Technician', 'JobRole_Manager',
       'JobRole_Manufacturing Director', 'JobRole_Research Director',
       'JobRole_Research Scientist', 'JobRole_Sales Executive',
       'JobRole_Sales Representative', 'Education_1', 'Education_2',
       'Education_3', 'Education_4', 'Education_5',
       'EducationField_Human Resources', 'EducationField_Life Sciences',
       'EducationField_Marketing', 'EducationField_Medical',
       'EducationField_Other', 'EducationField_Technical Degree',
       'Department_Human Resources', 'Department_Research & Development',
       'Department_Sales']]
y = emp.Attrition

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=903)

# %%
model = LogisticRegression(max_iter=100000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=100000)

# %%
predict = model.predict(X_test)

# %%
print(classification_report(y_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.93       374
#            1       0.74      0.21      0.33        67
#
#     accuracy                           0.87       441
#    macro avg       0.81      0.60      0.63       441
# weighted avg       0.85      0.87      0.84       441

# %%
accuracies = {}
acc = model.score(X_test,y_test)*100
accuracies['Logistic Regression'] = acc
print("Test Accuracy {:.2f}%".format(acc))
# Out:
# Test Accuracy 86.85%
